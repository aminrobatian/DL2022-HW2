# %% [markdown]
# # Deep Learning
# ## HW2 - Problem 1
#
# Name: Amin Robatian
#
# Student Number: 400301075

# %%
import torch
import random
import numpy as np
import matplotlib.pyplot as plt
from math import floor

# %matplotlib inline

torch.manual_seed(30)
random.seed(30)
np.random.seed(30)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cpu device

# %% [markdown]
# # Part (A) - Adding Dataset

# %%
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor

training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)

test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to data/FashionMNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/26421880 [00:00<?, ?it/s]
# Extracting data/FashionMNIST/raw/train-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/29515 [00:00<?, ?it/s]
# Extracting data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/4422102 [00:00<?, ?it/s]
# Extracting data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/5148 [00:00<?, ?it/s]
# Extracting data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw

# %%
labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}

plotted_classes = []
i = 0
figure = plt.figure(figsize=(8, 8))
rows, cols = 4, 5

while len(plotted_classes) != 10:
  sample_idx = torch.randint(len(training_data), size=(1,)).item()
  img, label = training_data[sample_idx]
  if label not in plotted_classes:
    plotted_classes.append(label)
    i += 1
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")  
    
plt.show()

# %% [markdown]
# # Part (B) - Network Implementation

# %%
W1 = torch.randn(256, 28*28, requires_grad=True)
b1 = torch.randn(256, 1, requires_grad=True)

W2 = torch.randn(128, 256, requires_grad=True)
b2 = torch.randn(128, 1, requires_grad=True)

W3 = torch.randn(64, 128, requires_grad=True)
b3 = torch.randn(64, 1, requires_grad=True)

W4 = torch.randn(10, 64, requires_grad=True)
b4 = torch.randn(10, 1, requires_grad=True)

# %%
def ReLU(x):
  z = torch.zeros_like(x)
  y = torch.maximum(x, z)
  return y


def tanh(x):
  y = (torch.exp(x) - torch.exp(-1 * x)) / (torch.exp(x) + torch.exp(-1 * x))
  return y

def softmax(x):
  k , m, n = x.shape
  y =  torch.zeros_like(x)
  for i in range(k):
    v = x[i, :, :]
    y[i, :, :] = torch.exp(v) / torch.sum(torch.exp(v))
  return y

# %%
def model(xb):
  global W1, b1, W2, b2, W3, b3, W4, b4
  y1 = torch.matmul(W1, xb) + b1
  y1 = tanh(y1)

  y2 = torch.matmul(W2, y1) + b2
  y2 = tanh(y2)

  y3 = torch.matmul(W3, y2) + b3
  y3 = tanh(y3)

  y4 = torch.matmul(W4, y3) + b4
  y4 = tanh(y4)

  yb = softmax(y4)
  return yb

# %% [markdown]
# # Part (C) - Model Training

# %%
learning_rate = 1e-1
batch_size = 100
epochs = 100

# %%
from torchvision.transforms import ToTensor, Lambda

training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
    target_transform = Lambda(lambda y: torch.zeros(10, dtype=torch.float).scatter_(dim=0, index=torch.tensor(y),
                                                                                    value=1))
)

test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
    target_transform = Lambda(lambda y: torch.zeros(10, dtype=torch.float).scatter_(dim=0, index=torch.tensor(y),
                                                                                    value=1))
)

# %%
from torch.utils.data import DataLoader

train_dataloader = DataLoader(training_data, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=batch_size, shuffle=True)

# %%
def BinaryCrossEntropy(y_hat, y):
  BCE =  (-1 / batch_size) * torch.sum(y * torch.log(y_hat) + (1 - y) * torch.log(1 - y_hat))
  return BCE

# %%
def TrainDataSet_Accuracy(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    train_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            X = torch.reshape(X, (batch_size, 28*28, 1))
            y = torch.reshape(y, (batch_size, 10, 1))
            pred = model(X)
            train_loss += loss_fn(pred, y).item()
            #
            for i in range(batch_size):
              v1 = pred[i, :, :]
              v2 = y[i, :, :]
              if torch.argmax(v1) == torch.argmax(v2):
                correct += 1
            #correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    train_loss /= num_batches
    correct /= size
    print(f"Train Dataset: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {train_loss:>8f} \n")

# %%
def TestDataSet_Accuracy(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            X = torch.reshape(X, (batch_size, 28*28, 1))
            y = torch.reshape(y, (batch_size, 10, 1))
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            #
            for i in range(batch_size):
              v1 = pred[i, :, :]
              v2 = y[i, :, :]
              if torch.argmax(v1) == torch.argmax(v2):
                correct += 1
            #correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Test Dataset: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
def train_loop(dataloader, model, loss_fn):
    global W1, b1, W2, b2, W3, b3, W4, b4
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        X = torch.reshape(X, (batch_size, 28*28, 1))
        y = torch.reshape(y, (batch_size, 10, 1))
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)
        # Backpropagation
        # computes the derivative of the loss w.r.t. the parameters
        loss.backward()
        # one step of SGD
        # clear old gradients from the last step
        with torch.no_grad():
          W1 -= learning_rate * W1.grad
          b1 -= learning_rate * b1.grad
          W2 -= learning_rate * W2.grad
          b2 -= learning_rate * b2.grad
          W3 -= learning_rate * W3.grad
          b3 -= learning_rate * b3.grad
          W4 -= learning_rate * W4.grad
          b4 -= learning_rate * b4.grad
          W1.grad.zero_()
          b1.grad.zero_()
          W2.grad.zero_()
          b2.grad.zero_()
          W3.grad.zero_()
          b3.grad.zero_()
          W4.grad.zero_()
          b4.grad.zero_()

# %%
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, model, loss_fn=BinaryCrossEntropy)
    TrainDataSet_Accuracy(train_dataloader, model, loss_fn=BinaryCrossEntropy)
    TestDataSet_Accuracy(test_dataloader, model, loss_fn=BinaryCrossEntropy)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Train Dataset:
#  Accuracy: 35.7%, Avg loss: 2.633240
#
# Test Dataset:
#  Accuracy: 34.7%, Avg loss: 2.648171
#
# Epoch 2
# -------------------------------
# Train Dataset:
#  Accuracy: 50.8%, Avg loss: 2.289886
#
# Test Dataset:
#  Accuracy: 50.2%, Avg loss: 2.316006
#
# Epoch 3
# -------------------------------
# Train Dataset:
#  Accuracy: 55.9%, Avg loss: 2.156626
#
# Test Dataset:
#  Accuracy: 54.8%, Avg loss: 2.173640
#
# Epoch 4
# -------------------------------
# Train Dataset:
#  Accuracy: 59.8%, Avg loss: 2.093387
#
# Test Dataset:
#  Accuracy: 58.9%, Avg loss: 2.115684
#
# Epoch 5
# -------------------------------
# Train Dataset:
#  Accuracy: 61.8%, Avg loss: 2.040582
#
# Test Dataset:
#  Accuracy: 60.5%, Avg loss: 2.064454
#
# Epoch 6
# -------------------------------
# Train Dataset:
#  Accuracy: 64.1%, Avg loss: 2.015211
#
# Test Dataset:
#  Accuracy: 63.2%, Avg loss: 2.032914
#
# Epoch 7
# -------------------------------
# Train Dataset:
#  Accuracy: 66.4%, Avg loss: 1.988501
#
# Test Dataset:
#  Accuracy: 65.3%, Avg loss: 2.007793
#
# Epoch 8
# -------------------------------
# Train Dataset:
#  Accuracy: 67.7%, Avg loss: 1.958264
#
# Test Dataset:
#  Accuracy: 66.3%, Avg loss: 1.986053
#
# Epoch 9
# -------------------------------
# Train Dataset:
#  Accuracy: 68.0%, Avg loss: 1.940692
#
# Test Dataset:
#  Accuracy: 67.1%, Avg loss: 1.965111
#
# Epoch 10
# -------------------------------
# Train Dataset:
#  Accuracy: 69.4%, Avg loss: 1.925035
#
# Test Dataset:
#  Accuracy: 68.3%, Avg loss: 1.952588
#
# Epoch 11
# -------------------------------
# Train Dataset:
#  Accuracy: 70.0%, Avg loss: 1.912737
#
# Test Dataset:
#  Accuracy: 69.1%, Avg loss: 1.937271
#
# Epoch 12
# -------------------------------
# Train Dataset:
#  Accuracy: 69.5%, Avg loss: 1.903896
#
# Test Dataset:
#  Accuracy: 68.8%, Avg loss: 1.928596
#
# Epoch 13
# -------------------------------
# Train Dataset:
#  Accuracy: 70.3%, Avg loss: 1.890243
#
# Test Dataset:
#  Accuracy: 69.9%, Avg loss: 1.924464
#
# Epoch 14
# -------------------------------
# Train Dataset:
#  Accuracy: 71.4%, Avg loss: 1.886223
#
# Test Dataset:
#  Accuracy: 70.9%, Avg loss: 1.909423
#
# Epoch 15
# -------------------------------
# Train Dataset:
#  Accuracy: 72.0%, Avg loss: 1.876118
#
# Test Dataset:
#  Accuracy: 71.3%, Avg loss: 1.907643
#
# Epoch 16
# -------------------------------
# Train Dataset:
#  Accuracy: 72.2%, Avg loss: 1.859633
#
# Test Dataset:
#  Accuracy: 71.2%, Avg loss: 1.891066
#
# Epoch 17
# -------------------------------
# Train Dataset:
#  Accuracy: 73.0%, Avg loss: 1.853128
#
# Test Dataset:
#  Accuracy: 71.9%, Avg loss: 1.883143
#
# Epoch 18
# -------------------------------
# Train Dataset:
#  Accuracy: 74.1%, Avg loss: 1.851785
#
# Test Dataset:
#  Accuracy: 73.5%, Avg loss: 1.875133
#
# Epoch 19
# -------------------------------
# Train Dataset:
#  Accuracy: 74.9%, Avg loss: 1.836406
#
# Test Dataset:
#  Accuracy: 73.8%, Avg loss: 1.864610
#
# Epoch 20
# -------------------------------
# Train Dataset:
#  Accuracy: 74.4%, Avg loss: 1.839782
#
# Test Dataset:
#  Accuracy: 73.7%, Avg loss: 1.872630
#
# Epoch 21
# -------------------------------
# Train Dataset:
#  Accuracy: 74.8%, Avg loss: 1.828801
#
# Test Dataset:
#  Accuracy: 74.0%, Avg loss: 1.864408
#
# Epoch 22
# -------------------------------
# Train Dataset:
#  Accuracy: 75.7%, Avg loss: 1.818081
#
# Test Dataset:
#  Accuracy: 75.0%, Avg loss: 1.851817
#
# Epoch 23
# -------------------------------
# Train Dataset:
#  Accuracy: 75.6%, Avg loss: 1.819975
#
# Test Dataset:
#  Accuracy: 74.7%, Avg loss: 1.858665
#
# Epoch 24
# -------------------------------
# Train Dataset:
#  Accuracy: 75.9%, Avg loss: 1.813179
#
# Test Dataset:
#  Accuracy: 74.9%, Avg loss: 1.853157
#
# Epoch 25
# -------------------------------
# Train Dataset:
#  Accuracy: 76.6%, Avg loss: 1.808704
#
# Test Dataset:
#  Accuracy: 75.4%, Avg loss: 1.848354
#
# Epoch 26
# -------------------------------
# Train Dataset:
#  Accuracy: 77.0%, Avg loss: 1.801689
#
# Test Dataset:
#  Accuracy: 76.8%, Avg loss: 1.832165
#
# Epoch 27
# -------------------------------
# Train Dataset:
#  Accuracy: 77.2%, Avg loss: 1.791699
#
# Test Dataset:
#  Accuracy: 76.1%, Avg loss: 1.833463
#
# Epoch 28
# -------------------------------
# Train Dataset:
#  Accuracy: 78.0%, Avg loss: 1.786971
#
# Test Dataset:
#  Accuracy: 77.0%, Avg loss: 1.823795
#
# Epoch 29
# -------------------------------
# Train Dataset:
#  Accuracy: 78.1%, Avg loss: 1.783800
#
# Test Dataset:
#  Accuracy: 76.8%, Avg loss: 1.814756
#
# Epoch 30
# -------------------------------
# Train Dataset:
#  Accuracy: 78.4%, Avg loss: 1.780209
#
# Test Dataset:
#  Accuracy: 77.8%, Avg loss: 1.814206
#
# Epoch 31
# -------------------------------
# Train Dataset:
#  Accuracy: 78.8%, Avg loss: 1.774364
#
# Test Dataset:
#  Accuracy: 77.8%, Avg loss: 1.804741
#
# Epoch 32
# -------------------------------
# Train Dataset:
#  Accuracy: 78.8%, Avg loss: 1.773254
#
# Test Dataset:
#  Accuracy: 77.6%, Avg loss: 1.811654
#
# Epoch 33
# -------------------------------
# Train Dataset:
#  Accuracy: 79.3%, Avg loss: 1.762987
#
# Test Dataset:
#  Accuracy: 78.3%, Avg loss: 1.801621
#
# Epoch 34
# -------------------------------
# Train Dataset:
#  Accuracy: 79.7%, Avg loss: 1.761772
#
# Test Dataset:
#  Accuracy: 78.8%, Avg loss: 1.795265
#
# Epoch 35
# -------------------------------
# Train Dataset:
#  Accuracy: 79.8%, Avg loss: 1.753412
#
# Test Dataset:
#  Accuracy: 78.3%, Avg loss: 1.785581
#
# Epoch 36
# -------------------------------
# Train Dataset:
#  Accuracy: 79.5%, Avg loss: 1.759172
#
# Test Dataset:
#  Accuracy: 78.2%, Avg loss: 1.792982
#
# Epoch 37
# -------------------------------
# Train Dataset:
#  Accuracy: 79.9%, Avg loss: 1.748733
#
# Test Dataset:
#  Accuracy: 78.6%, Avg loss: 1.785495
#
# Epoch 38
# -------------------------------
# Train Dataset:
#  Accuracy: 80.5%, Avg loss: 1.743196
#
# Test Dataset:
#  Accuracy: 78.9%, Avg loss: 1.785543
#
# Epoch 39
# -------------------------------
# Train Dataset:
#  Accuracy: 80.3%, Avg loss: 1.744782
#
# Test Dataset:
#  Accuracy: 78.4%, Avg loss: 1.779358
#
# Epoch 40
# -------------------------------
# Train Dataset:
#  Accuracy: 80.4%, Avg loss: 1.738427
#
# Test Dataset:
#  Accuracy: 79.1%, Avg loss: 1.777313
#
# Epoch 41
# -------------------------------
# Train Dataset:
#  Accuracy: 80.6%, Avg loss: 1.734321
#
# Test Dataset:
#  Accuracy: 79.1%, Avg loss: 1.781519
#
# Epoch 42
# -------------------------------
# Train Dataset:
#  Accuracy: 80.9%, Avg loss: 1.734053
#
# Test Dataset:
#  Accuracy: 79.2%, Avg loss: 1.777519
#
# Epoch 43
# -------------------------------
# Train Dataset:
#  Accuracy: 81.2%, Avg loss: 1.726072
#
# Test Dataset:
#  Accuracy: 79.8%, Avg loss: 1.773404
#
# Epoch 44
# -------------------------------
# Train Dataset:
#  Accuracy: 81.1%, Avg loss: 1.725225
#
# Test Dataset:
#  Accuracy: 79.5%, Avg loss: 1.773022
#
# Epoch 45
# -------------------------------
# Train Dataset:
#  Accuracy: 81.3%, Avg loss: 1.721372
#
# Test Dataset:
#  Accuracy: 79.6%, Avg loss: 1.766463
#
# Epoch 46
# -------------------------------
# Train Dataset:
#  Accuracy: 80.9%, Avg loss: 1.724546
#
# Test Dataset:
#  Accuracy: 79.3%, Avg loss: 1.771006
#
# Epoch 47
# -------------------------------
# Train Dataset:
#  Accuracy: 81.7%, Avg loss: 1.711959
#
# Test Dataset:
#  Accuracy: 79.9%, Avg loss: 1.765882
#
# Epoch 48
# -------------------------------
# Train Dataset:
#  Accuracy: 81.8%, Avg loss: 1.708595
#
# Test Dataset:
#  Accuracy: 79.8%, Avg loss: 1.763078
#
# Epoch 49
# -------------------------------
# Train Dataset:
#  Accuracy: 81.7%, Avg loss: 1.706483
#
# Test Dataset:
#  Accuracy: 79.7%, Avg loss: 1.762310
#
# Epoch 50
# -------------------------------
# Train Dataset:
#  Accuracy: 81.7%, Avg loss: 1.709434
#
# Test Dataset:
#  Accuracy: 80.2%, Avg loss: 1.761883
#
# Epoch 51
# -------------------------------
# Train Dataset:
#  Accuracy: 81.9%, Avg loss: 1.711273
#
# Test Dataset:
#  Accuracy: 79.9%, Avg loss: 1.759055
#
# Epoch 52
# -------------------------------
# Train Dataset:
#  Accuracy: 82.1%, Avg loss: 1.701049
#
# Test Dataset:
#  Accuracy: 80.7%, Avg loss: 1.752103
#
# Epoch 53
# -------------------------------
# Train Dataset:
#  Accuracy: 82.2%, Avg loss: 1.704769
#
# Test Dataset:
#  Accuracy: 80.6%, Avg loss: 1.754803
#
# Epoch 54
# -------------------------------
# Train Dataset:
#  Accuracy: 82.3%, Avg loss: 1.698591
#
# Test Dataset:
#  Accuracy: 80.5%, Avg loss: 1.749325
#
# Epoch 55
# -------------------------------
# Train Dataset:
#  Accuracy: 82.4%, Avg loss: 1.696016
#
# Test Dataset:
#  Accuracy: 80.6%, Avg loss: 1.750790
#
# Epoch 56
# -------------------------------
# Train Dataset:
#  Accuracy: 82.6%, Avg loss: 1.692798
#
# Test Dataset:
#  Accuracy: 80.8%, Avg loss: 1.739344
#
# Epoch 57
# -------------------------------
# Train Dataset:
#  Accuracy: 82.7%, Avg loss: 1.689055
#
# Test Dataset:
#  Accuracy: 81.0%, Avg loss: 1.746005
#
# Epoch 58
# -------------------------------
# Train Dataset:
#  Accuracy: 82.8%, Avg loss: 1.686703
#
# Test Dataset:
#  Accuracy: 81.0%, Avg loss: 1.742656
#
# Epoch 59
# -------------------------------
# Train Dataset:
#  Accuracy: 83.1%, Avg loss: 1.683404
#
# Test Dataset:
#  Accuracy: 81.0%, Avg loss: 1.744592
#
# Epoch 60
# -------------------------------
# Train Dataset:
#  Accuracy: 83.0%, Avg loss: 1.684494
#
# Test Dataset:
#  Accuracy: 81.2%, Avg loss: 1.740970
#
# Epoch 61
# -------------------------------
# Train Dataset:
#  Accuracy: 82.8%, Avg loss: 1.680958
#
# Test Dataset:
#  Accuracy: 81.0%, Avg loss: 1.743466
#
# Epoch 62
# -------------------------------
# Train Dataset:
#  Accuracy: 83.2%, Avg loss: 1.679326
#
# Test Dataset:
#  Accuracy: 80.9%, Avg loss: 1.743042
#
# Epoch 63
# -------------------------------
# Train Dataset:
#  Accuracy: 83.1%, Avg loss: 1.680583
#
# Test Dataset:
#  Accuracy: 81.4%, Avg loss: 1.737994
#
# Epoch 64
# -------------------------------
# Train Dataset:
#  Accuracy: 83.0%, Avg loss: 1.678298
#
# Test Dataset:
#  Accuracy: 81.1%, Avg loss: 1.737349
#
# Epoch 65
# -------------------------------
# Train Dataset:
#  Accuracy: 83.0%, Avg loss: 1.679955
#
# Test Dataset:
#  Accuracy: 81.0%, Avg loss: 1.739127
#
# Epoch 66
# -------------------------------
# Train Dataset:
#  Accuracy: 83.3%, Avg loss: 1.674137
#
# Test Dataset:
#  Accuracy: 81.1%, Avg loss: 1.735840
#
# Epoch 67
# -------------------------------
# Train Dataset:
#  Accuracy: 83.5%, Avg loss: 1.671338
#
# Test Dataset:
#  Accuracy: 81.3%, Avg loss: 1.730694
#
# Epoch 68
# -------------------------------
# Train Dataset:
#  Accuracy: 83.6%, Avg loss: 1.670430
#
# Test Dataset:
#  Accuracy: 81.3%, Avg loss: 1.731846
#
# Epoch 69
# -------------------------------
# Train Dataset:
#  Accuracy: 83.6%, Avg loss: 1.669325
#
# Test Dataset:
#  Accuracy: 81.9%, Avg loss: 1.729566
#
# Epoch 70
# -------------------------------
# Train Dataset:
#  Accuracy: 83.7%, Avg loss: 1.667950
#
# Test Dataset:
#  Accuracy: 81.6%, Avg loss: 1.728954
#
# Epoch 71
# -------------------------------
# Train Dataset:
#  Accuracy: 83.7%, Avg loss: 1.664472
#
# Test Dataset:
#  Accuracy: 81.5%, Avg loss: 1.730693
#
# Epoch 72
# -------------------------------
# Train Dataset:
#  Accuracy: 83.8%, Avg loss: 1.662023
#
# Test Dataset:
#  Accuracy: 81.6%, Avg loss: 1.729698
#
# Epoch 73
# -------------------------------
# Train Dataset:
#  Accuracy: 83.8%, Avg loss: 1.661891
#
# Test Dataset:
#  Accuracy: 81.3%, Avg loss: 1.729993
#
# Epoch 74
# -------------------------------
# Train Dataset:
#  Accuracy: 83.9%, Avg loss: 1.661390
#
# Test Dataset:
#  Accuracy: 81.7%, Avg loss: 1.728160
#
# Epoch 75
# -------------------------------
# Train Dataset:
#  Accuracy: 83.8%, Avg loss: 1.659557
#
# Test Dataset:
#  Accuracy: 81.4%, Avg loss: 1.729789
#
# Epoch 76
# -------------------------------
# Train Dataset:
#  Accuracy: 84.1%, Avg loss: 1.657719
#
# Test Dataset:
#  Accuracy: 81.8%, Avg loss: 1.728434
#
# Epoch 77
# -------------------------------
# Train Dataset:
#  Accuracy: 84.0%, Avg loss: 1.657523
#
# Test Dataset:
#  Accuracy: 81.4%, Avg loss: 1.730640
#
# Epoch 78
# -------------------------------
# Train Dataset:
#  Accuracy: 83.9%, Avg loss: 1.659361
#
# Test Dataset:
#  Accuracy: 81.3%, Avg loss: 1.729902
#
# Epoch 79
# -------------------------------
# Train Dataset:
#  Accuracy: 84.3%, Avg loss: 1.651402
#
# Test Dataset:
#  Accuracy: 81.8%, Avg loss: 1.722817
#
# Epoch 80
# -------------------------------
# Train Dataset:
#  Accuracy: 84.0%, Avg loss: 1.651817
#
# Test Dataset:
#  Accuracy: 81.7%, Avg loss: 1.724297
#
# Epoch 81
# -------------------------------
# Train Dataset:
#  Accuracy: 84.5%, Avg loss: 1.645189
#
# Test Dataset:
#  Accuracy: 81.9%, Avg loss: 1.726193
#
# Epoch 82
# -------------------------------
# Train Dataset:
#  Accuracy: 84.5%, Avg loss: 1.645309
#
# Test Dataset:
#  Accuracy: 81.9%, Avg loss: 1.720959
#
# Epoch 83
# -------------------------------
# Train Dataset:
#  Accuracy: 84.4%, Avg loss: 1.646541
#
# Test Dataset:
#  Accuracy: 81.9%, Avg loss: 1.722786
#
# Epoch 84
# -------------------------------
# Train Dataset:
#  Accuracy: 84.5%, Avg loss: 1.643221
#
# Test Dataset:
#  Accuracy: 81.9%, Avg loss: 1.720216
#
# Epoch 85
# -------------------------------
# Train Dataset:
#  Accuracy: 84.7%, Avg loss: 1.641493
#
# Test Dataset:
#  Accuracy: 81.9%, Avg loss: 1.718375
#
# Epoch 86
# -------------------------------
# Train Dataset:
#  Accuracy: 84.5%, Avg loss: 1.640170
#
# Test Dataset:
#  Accuracy: 82.2%, Avg loss: 1.717958
#
# Epoch 87
# -------------------------------
# Train Dataset:
#  Accuracy: 84.7%, Avg loss: 1.638511
#
# Test Dataset:
#  Accuracy: 82.2%, Avg loss: 1.718878
#
# Epoch 88
# -------------------------------
# Train Dataset:
#  Accuracy: 85.0%, Avg loss: 1.631021
#
# Test Dataset:
#  Accuracy: 82.3%, Avg loss: 1.714844
#
# Epoch 89
# -------------------------------
# Train Dataset:
#  Accuracy: 84.9%, Avg loss: 1.632713
#
# Test Dataset:
#  Accuracy: 82.3%, Avg loss: 1.721780
#
# Epoch 90
# -------------------------------
# Train Dataset:
#  Accuracy: 85.0%, Avg loss: 1.632475
#
# Test Dataset:
#  Accuracy: 82.3%, Avg loss: 1.718316
#
# Epoch 91
# -------------------------------
# Train Dataset:
#  Accuracy: 85.0%, Avg loss: 1.633152
#
# Test Dataset:
#  Accuracy: 82.2%, Avg loss: 1.718106
#
# Epoch 92
# -------------------------------
# Train Dataset:
#  Accuracy: 85.0%, Avg loss: 1.629339
#
# Test Dataset:
#  Accuracy: 82.5%, Avg loss: 1.715566
#
# Epoch 93
# -------------------------------
# Train Dataset:
#  Accuracy: 85.1%, Avg loss: 1.630822
#
# Test Dataset:
#  Accuracy: 82.3%, Avg loss: 1.715719
#
# Epoch 94
# -------------------------------
# Train Dataset:
#  Accuracy: 85.2%, Avg loss: 1.623807
#
# Test Dataset:
#  Accuracy: 82.3%, Avg loss: 1.713735
#
# Epoch 95
# -------------------------------
# Train Dataset:
#  Accuracy: 85.5%, Avg loss: 1.622385
#
# Test Dataset:
#  Accuracy: 82.3%, Avg loss: 1.715138
#
# Epoch 96
# -------------------------------
# Train Dataset:
#  Accuracy: 85.3%, Avg loss: 1.625634
#
# Test Dataset:
#  Accuracy: 82.4%, Avg loss: 1.713387
#
# Epoch 97
# -------------------------------
# Train Dataset:
#  Accuracy: 85.5%, Avg loss: 1.622588
#
# Test Dataset:
#  Accuracy: 82.2%, Avg loss: 1.714042
#
# Epoch 98
# -------------------------------
# Train Dataset:
#  Accuracy: 85.3%, Avg loss: 1.623179
#
# Test Dataset:
#  Accuracy: 82.3%, Avg loss: 1.715446
#
# Epoch 99
# -------------------------------
# Train Dataset:
#  Accuracy: 85.5%, Avg loss: 1.617031
#
# Test Dataset:
#  Accuracy: 82.2%, Avg loss: 1.714755
#
# Epoch 100
# -------------------------------
# Train Dataset:
#  Accuracy: 85.7%, Avg loss: 1.615145
#
# Test Dataset:
#  Accuracy: 82.5%, Avg loss: 1.718629
#
# Done!

# %% [markdown]
# # Part (D) - Model Testing

# %%
print('Model Accuracy on Test Data \n-------------------------------')
TestDataSet_Accuracy(test_dataloader, model, loss_fn=BinaryCrossEntropy)
# Out:
# Model Accuracy on Test Data
# -------------------------------
# Test Dataset:
#  Accuracy: 82.5%, Avg loss: 1.718629

# %%
labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}

figure = plt.figure(figsize=(40, 40))
rows, cols = 20, 1
i = 0
for j in range(9):
  i += 1
  sample_idx = torch.randint(len(test_data), size=(1,)).item()
  img, label = test_data[sample_idx]
  #
  with torch.no_grad():
    X = torch.reshape(img, (1, 28*28, 1))
    pred = model(X)
  figure.add_subplot(rows, cols, i)
  label_true = labels_map[torch.argmax(label).item()]
  label_predicted = labels_map[torch.argmax(pred).item()]
  plt.title(f"True Label: {label_true},  Predicted Label: {label_predicted}")
  plt.axis("off")
  plt.imshow(img.squeeze(), cmap="gray") 
  
plt.show()
